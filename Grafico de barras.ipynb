# %% [markdown]
# # Grafico de barras verticais

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


x=pd.read_excel("C:/Users/User2/Desktop/Programação/Data Science/Banco de dados/737822_1290921_bundle_archive/file.xlsx")

xgrafico=x["State / Union territory (UT)"]
ygrafico=x["National Share (%)"]

plt.bar(xgrafico,ygrafico,color="green")
# Out:
# C:\Users\User2\Anaconda3\lib\site-packages\ipykernel\parentpoller.py:116: UserWarning: Parent poll failed.  If the frontend dies,
#                 the kernel may be left running.  Please let us know
#                 about your system (bitness, Python, etc.) at
#                 ipython-dev@scipy.org
#   ipython-dev@scipy.org""")
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-b168fc6076ad> in <module>()
# ----> 1 import numpy as np
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#       4
#       5
#
# ~\Anaconda3\lib\site-packages\numpy\__init__.py in <module>()
#     138     from . import _distributor_init
#     139
# --> 140     from . import core
#     141     from .core import *
#     142     from . import compat
#
# ~\Anaconda3\lib\site-packages\numpy\core\__init__.py in <module>()
#      66         "numpy in {}. One method of fixing this is to repeatedly uninstall "
#      67         "numpy until none is found, then reinstall this version.")
# ---> 68     raise ImportError(msg.format(path))
#      69
#      70 from . import numerictypes as nt
#
# ImportError: Something is wrong with the numpy installation. While importing we detected an older version of numpy in ['C:\\Users\\User2\\Anaconda3\\lib\\site-packages\\numpy']. One method of fixing this is to repeatedly uninstall numpy until none is found, then reinstall this version.

# %% [markdown]
# # Grafico de barras horizontais

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


x=pd.read_excel("C:/Users/User2/Desktop/Programação/Data Science/Banco de dados/737822_1290921_bundle_archive/file.xlsx")

ygrafico=x["State / Union territory (UT)"]
xgrafico=x["Area (km2)"]

plt.barh(ygrafico,xgrafico,color="green")
# Out:
# <BarContainer object of 34 artists>

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

pd.set_option('display.max_columns', None)  
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', -1)

df=pd.read_excel("C:/Users/User2/Desktop/Programação/Data Science/Banco de dados/Titanic/titanic/train.xlsx")



 #Mortes na classe alta
Calta=(df.loc[(df["Pclass"]==3)])
Nalta=Calta["Pclass"].count()

xalta=(df.loc[(df["Survived"]==0) & (df["Pclass"]==3)])
Malta= xalta["Pclass"].count()

Mortalidade_alta=Malta/Nalta

#Mortes na classe media
Cmedia=(df.loc[(df["Pclass"]==2)])
Nmedia=Cmedia["Pclass"].count()

xmedia=(df.loc[(df["Survived"]==0) & (df["Pclass"]==2)])
Mmedia= xmedia["Pclass"].count()

Mortalidade_media=Mmedia/Nmedia

#Mortes na classe baixa

Cbaixa=(df.loc[(df["Pclass"]==1)])
Nbaixa=Cbaixa["Pclass"].count()

xbaixa=(df.loc[(df["Survived"]==0) & (df["Pclass"]==1)])
Mbaixa= xbaixa["Pclass"].count()

Mortalidade_baixa=Mbaixa/Nbaixa

#graficos 

xgrafico1=["1","2","3"]
ygrafico1=[Mortalidade_alta,Mortalidade_media,Mortalidade_baixa]
plt.bar(xgrafico1,ygrafico1, color="red")
# Out:
# <BarContainer object of 3 artists>

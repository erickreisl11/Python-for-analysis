# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

x=pd.read_excel("C:/Users/User2/Desktop/Programação/Data Science/Banco de dados/Nascimentos.xlsx")
plt.plot(x["ano"],x["taxa"])
plt.show()

# %%
y=np.array(x["ano"][0:])
y
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015], dtype=int64)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_excel("C:/Users/User2/Desktop/Programação/Data Science/Banco de dados/ebola_2014_2016_clean.xlsx")
Gui=df.loc[df["Country"]=='Guinea']
Sie=df.loc[df["Country"]=='Sierra Leone']


plt.plot(Gui["Date"],Gui["No. of confirmed deaths"],color='red')
plt.plot(Sie["Date"],Sie["No. of confirmed deaths"])

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_excel("C:/Users/User2/Desktop/Programação/Data Science/Banco de dados/caso_full.xlsx")

Gui=df.loc[df["city"]=='São Paulo']

plt.plot(Gui["date"],Gui["new_confirmed"],color='red')

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

dg=pd.read_excel("C:/Users/User2/Desktop/Programação/Data Science/Banco de dados/hospital-bed-capacity-and-covid19/Dados1.xlsx")
g=dg.iloc[3:170,:]

plt.hist(g["Adult Population"],bins=15)
plt.show()

# %%
dg.iloc[3:7,:]
# Out:
#                   HRR  Total Hospital Beds  Total ICU Beds  \
# 3  Alameda County. CA               2695.0           293.0
# 4          Albany. GA                704.0            60.0
# 5          Albany. NY               4804.0           425.0
# 6     Albuquerque. NM               2908.0           380.0
#
#    Available Hospital Beds  Potentially Available Hospital Beds*  \
# 3                    665.0                                  1.68
# 4                    221.0                                462.00
# 5                   1579.0                               3191.00
# 6                   1102.0                               2005.00
#
#    Available ICU Beds  Potentially Available ICU Beds*  Adult Population  \
# 3               139.0                            216.0         1310189.0
# 4                27.0                             43.0          157143.0
# 5               193.0                            309.0         1477723.0
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

dg=pd.read_excel("C:/Users/User2/Desktop/Programação/Data Science/Banco de dados/hospital-bed-capacity-and-covid19/Dados1.xlsx")
g=dg.iloc[5,3:7]

plt.pie(g,labels=["Available Hospital Beds","Potentially Available Hospital Beds*","Available ICU Beds","Potentially Available ICU Beds*"],autopct="%1.0f%%")
plt.show()

# %%
g
# Out:
# Available Hospital Beds                 1579
# Potentially Available Hospital Beds*    3191
# Available ICU Beds                       193
# Potentially Available ICU Beds*          309
# Name: 5, dtype: object
